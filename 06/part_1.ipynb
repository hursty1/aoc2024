# %%
# grid = []
with open('data_full.txt', 'r') as f:
    grid = [list(line.strip()) for line in f]

# %%
grid
# Out:
# [['.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
# ...

# %%
def start(grid):
    for y in range(0, len(grid)):
        for x in range(0, len(grid[y])):
            if grid[y][x] == '^':
                return (y, x)

# %%
def reset():
    with open('data_full.txt', 'r') as f:
        grid = [list(line.strip()) for line in f]

    sy, sx = start(grid)
    return sy, sx, grid

# %%
sy, sx = start(grid)
print(f'startx = {sx}, starty={sy}')
# Out:
# startx = 80, starty=58

# %%
directions = {
    '^': (0,-1),
    '>': (1,0),
    'v': (0,1),
    '<': (-1,0)
}

# %%
for d in directions:
    print(d)
# Out:
# ^
# >
# v
# <

# %%
#goal is to go form sx, sy to obstical
d = directions['^']
d
# Out:
# (0, -1)

# %%
for v in range(6):
    print(v)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
if d[1] < 0: #moving up
    moves = sy + d[1]
moves
# Out:
# 57

# %%
sy + d[1]
# Out:
# 57

# %%
if d[1] < 0:

    print(range(d[1] + sy))
    for v in range(sy-1, -1, d[1]):
        print(grid[v][sx])
        print(v)
        if grid[v][sx] == '#':
            print('rotate')
            break
# Out:
# range(0, 57)
# .
# 57
# .
# 56
# .
# 55
# .
# 54
# .
# 53
# .
# 52
# .
# 51
# .
# 50
# .
# 49
# .
# 48
# .
# 47
# .
# 46
# .
# 45
# .
# 44
# .
# 43
# .
# 42
# .
# 41
# .
# 40
# .
# 39
# .
# 38
# .
# 37
# .
# 36
# .
# 35
# .
# 34
# .
# 33
# .
# 32
# .
# 31
# .
# 30
# .
# 29
# .
# 28
# .
# 27
# .
# 26
# .
# 25
# #
# 24
# rotate

# %%
travel = True
dir = directions['^']
direction = '^'
sy, sx, grid = reset()
ngrid = grid
print(f'sx = {sx} sy = {sy}')
# Out:
# sx = 80 sy = 58

# %%
while travel:
    ##set direction
    if direction == '^': #up
        dir = directions[direction]
        for v in range((sy), -2, dir[1]):

            if ngrid[v][sx] == '#':
                sx = sx
                sy = v + 1
                direction = '>'
                # print(f'sx = {sx} sy = {sy}')
                break
            else:
                ngrid[v][sx] = 'X'
    if direction == '>': #up
        dir = directions[direction]
        for v in range(sx, len(grid[sy])+1, dir[0]):
            if ngrid[sy][v] == '#':
                sx = v -1
                sy = sy
                direction = 'v'
                # print(f'sx = {sx} sy = {sy}')
                break
            else:
                ngrid[sy][v] = 'X'
    if direction == 'v': #up
        dir = directions[direction]
        # print(dir)
        for v in range(sy, len(grid[sx])+1, dir[1]):
            # print(v)
            if ngrid[v][sx] == '#':
                sx = sx
                sy = v - 1 
                direction = '<'
                # print(f'sx = {sx} sy = {sy}')
                break
            else:
                ngrid[v][sx] = 'X'
    if direction == '<': #up
        dir = directions[direction]
        # print(dir)
        for v in range(sx, -2, dir[0]):
            # print(v)
            if ngrid[sy][v] == '#':
                sx = v + 1
                sy = sy 
                direction = '^'
                # print(f'sx = {sx} sy = {sy}')
                break
            else:
                ngrid[sy][v] = 'X'
    # print(sx, sy)
    # break

ngrid
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 31
#      28 # print(dir)
#      29 for v in range(sy, len(grid[sx])+1, dir[1]):
#      30     # print(v)
# ---> 31     if ngrid[v][sx] == '#':
#      32         sx = sx
#      33         sy = v - 1
#
# IndexError: list index out of range

# %%
ngrid
# Out:
# [['.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#',
#   '.',
#   '.',
#   '.',
#   '.',
# ...

# %%
count = 0
for y in range(len(ngrid)):
    for x in range(len(ngrid)):
        if ngrid[y][x]=='X':
            count +=1 
count
# Out:
# 4890

# %%
print(f'sx: {sx}: sy: {sy}') 
print(f'grid')
grid
